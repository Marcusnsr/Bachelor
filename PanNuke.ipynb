# %% [markdown]
# # Visualzing PanNuke dataset

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# Opening the images and labels
images = np.load('/Users/marcusnsr/Desktop/Bachelor/Fold1/images/fold1/images.npy')
labels = np.load('/Users/marcusnsr/Desktop/Bachelor/Fold1/masks/fold1/masks.npy')

# %%
images.shape
# Out:
# (2656, 256, 256, 3)

# %%
# Display test image:
plt.imshow(images[10])
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Filter out all cells except for Neutrophil cells:
labels = labels[:, :, :, 1]

# %%
# Plot the first image and its label
plt.imshow(images[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
